# %%
from llama_cpp import Llama
print("Cargando...")
# Intenta cargar un modelo dummy (o falla si no hay modelo, pero miramos los logs)
# Lo importante es ver qué imprime la librería al iniciarse.
try:
    llm = Llama(model_path="ruta_falsa.gguf", n_gpu_layers=-1, verbose=True)
except:
    pass

# %%
# Sección 0: Imports y configuración
from __future__ import annotations

import json
import re
from typing import Any, Dict

from llama_cpp import Llama
